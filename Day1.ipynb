# %%
no = int(input("Enter no: "))
res = no % 10
print(res)

# %%
no = int(input("Enter no: "))
n1 = no % 10
n2 = no // 10
res = n1 + n2
print(res)

# %%
no = int(input("Enter no: "))
n1 = no % 10
no = no // 10
n2 = no % 10
no = no // 10
n3 = no % 10

res = n1 + n2 + n3
print(res)

# %%
no = int(input("Enter no: "))
n1 = no % 10
no = no // 10
n2 = no % 10
no = no // 10
n3 = no % 10
no = no // 10
n4 = no % 10
no = no // 10
n5 = no % 10

res = n1 + n2 + n3 + n4 + n5
print(res)

# %%
no = int(input("Enter no: "))
n1 = no % 10
no = no // 10
n2 = no % 10
no = no // 10
n3 = no % 10

rev = n1 * 100 + n2 * 10 + n3 * 1
print(rev)

# %%
no = int(input("Enter no: "))
rev = 0
while no > 0:
    rem = no % 10
    rev = rev * 10 + rem
    no = no // 10
print(rev)

# %%
no = int(input("Enter no: "))
sum = 0
save = no

count = 0
temp_no = no
while temp_no > 0:
    temp_no = temp_no // 10
    count = count + 1

while no > 0:
    rem = no % 10
    sum = sum + (rem ** count)
    no = no // 10

if sum == save:
    print("no is armstrong")
else:
    print("no is not armstrong")

# %%
for i in range(1, 10001):
    no = i
    sum = 0
    save = no

    count = 0
    temp_no = no
    while temp_no > 0:
        temp_no = temp_no // 10
        count = count + 1
    no = save

    while no > 0:
        rem = no % 10
        sum = sum + (rem ** count)
        no = no // 10

    if sum == save:
        print("no is armstrong", i)

# %%
no = int(input("Enter no: "))
save = no
sum = 0

while no > 0:
    rem = no % 10
    fact = 1
    while rem > 0:
        fact = fact * rem
        rem = rem - 1
    sum = sum + fact
    no = no // 10

if save == sum:
    print("no is peterson")
else:
    print("no is not peterson")

# %%
n1 = 10
n2 = 20
n3 = 30
max_num = n1

if max_num < n2:
    max_num = n2
if max_num < n3:
    max_num = n3
print(max_num)

# %%
no = 5
if no % 2 == 0:
    print(no, "is even")
else:
    print(no, "is odd")

# %%
per = 75
if per >= 40 and per <= 60:
    print("Take admission in RBU")
elif per >= 61 and per <= 80:
    print("Take admission in YCCE")
elif per >= 81 and per <= 100:
    print("Take admission in VJTI")

# %%
no = int(input("Enter no: "))
fact = 1
while no > 0:
    fact = fact * no
    no = no - 1
print(fact)

# %%
no = int(input("Enter no: "))
rev = 0
save = no

while no > 0:
    rem = no % 10
    rev = rev * 10 + rem
    no = no // 10

if rev == save:
    print("no is palindrome")
else:
    print("no is not palindrome")

# %%
no = int(input("Enter no: "))
sum = 0
while no > 0:
    rem = no % 10
    sum = sum + rem
    no = no // 10
print(sum)

# %%
no = int(input("Enter no: "))
count = 0
while no > 0:
    no = no // 10
    count = count + 1
print(count)

# %%
a = 11.5
res = int(a)
print(res)

# %%
cp = int(input("Enter cost price: "))
st = input("Are you student y/n: ")

if st == 'y':
    if cp > 500:
        ds = cp * 0.10
    else:
        ds = cp * 0.5
else:
    if cp > 500:
        ds = cp * 0.8
    else:
        ds = cp * 0.2

net = cp - ds
print(f"Discount: {ds}, Net Price: {net}")

# %%
for i in range(10, 0, -1):
    print(i)

# %%
arr = [1, 2, 3, 4, 5, 5]

for i in range(len(arr)):
    print(arr[i])

for x in arr:
    print(x)

# %%
for i in range(1, 11):
    if i == 5:
        break
    print(i)

# %%
for i in range(1, 11):
    if i == 3:
        continue
    print(i)

# %%
i = 1
j = 10
while i < j:
    print(i, "\t", j)
    i = i + 1
    j = j - 1

# %%
arr = [5, 3, 2, 9, 8]
max_val = arr[0]
min_val = arr[0]

for i in range(1, len(arr)):
    if max_val < arr[i]:
        max_val = arr[i]
    if min_val > arr[i]:
        min_val = arr[i]

print("Max:", max_val)
print("Min:", min_val)

# %%
arr = [3, 2, 3, 1, 2, 4]
ans = []
for x in arr:
    if x not in ans:
        ans.append(x)
print(ans)
